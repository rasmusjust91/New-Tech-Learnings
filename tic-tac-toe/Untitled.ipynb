# %%
class Game:
    def __init__(self, bot=True):
        self.empty_symbol = '*'
        self.player_one = 'X'
        self.player_two = 'O'
        self.board = [
            [self.empty_symbol for _ in range(3)] 
            for _ in range(3)
        ]
        self.turn = 0
        
        self.who = self.player_one
        
        self.show_board()
        
        self.game_state = True
        
        self.bot = bot

    
    def show_board(self):
        print('\n'.join(['\t'.join([str(cell) for cell in row]) 
                         for row in self.board]))
    
    def __check_for_winner(self):
        
        # Check rows
        for row in self.board:
            s = sum([1 if row[i]==self.who else 0 for i in range(3)])
            if s==3:
                return True
                
        # Check cols
        for i in range(3):
            s = sum([1 if row[i] == self.who else 0 for row in self.board])
            if s==3:
                return True
            
        # Check diagonals
        if sum([1 if row[i]==self.who else 0 
                 for i, row in enumerate(self.board)]) == 3:
            return True
        
        if sum([1 if row[i]==self.who else 0 
                 for i, row in enumerate(reversed(self.board))]) == 3:
            return True
        
        return False
    
    def play_move(self):
        
        if self.who == self.player_one and self.bot:
            self.bot_play()
        else:
            self.human_play()
                
        self.show_board()
        
        if self.__check_for_winner():
            self.game_state = False
            print(f'{self.who} wins!!!!')
        
        self.turn += 1
    
        if self.turn == 9:
            self.game_state = False
            print('DRAW!!!!')
        
        if self.who == self.player_one:
            self.who = self.player_two
        else:
            self.who = self.player_one
    
    def human_play(self):
        while True:
            try:
                row = int(input(f'Enter row position for {game.who}: '))
                col = int(input(f'Enter col position for {game.who}: '))
                if self.board[row][col] == self.empty_symbol:
                    self.board[row][col] = self.who
                    break
                else:
                    print('Cant place here')
            except (IndexError, ValueError):
                print('Try Again')

                
    def bot_play(self):
        print(f'{self.who} (Bot) plays!')
        self.__find_best_board()
    
    def __find_best_board(self):
        board = self.board
        for i in range(3):
            for j in range(3):
                if board[i][j] == self.empty_symbol:
                    print('sf')

# %%
game = Game()

while game.game_state:
    game.play_move()
# Out:
# *	*	*
# *	*	*
# *	*	*
# X (Bot) plays!
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2
# *	*	*
# *	*	*
# *	*	*
# Enter row position for O: 0
# Enter col position for O: 0
# O	*	*
# *	*	*
# *	*	*
# X (Bot) plays!
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2
# O	*	*
# *	*	*
# *	*	*
# Enter row position for O: 0
# Enter col position for O: 1
# O	O	*
# *	*	*
# *	*	*
# X (Bot) plays!
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2
# O	O	*
# *	*	*
# *	*	*
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ...
